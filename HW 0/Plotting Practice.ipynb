# %%
import matplotlib.pyplot as plots
import numpy as np

xValues = np.arange(0, 5.25, 0.25)
    
plots.plot(xValues, np.exp(xValues), 'gs', xValues, np.exp(xValues), 'g--')

plots.xlabel('X Values')

plots.ylabel('Exponential Values')

plots.show()
