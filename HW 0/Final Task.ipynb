# %%
import matplotlib.pyplot as plots
import numpy as np

M = .6
E = np.arange(0, 1.05, .05)

while M <=.9:
    
    plots.plot(E, (1 - .35*E)*M + .35*E) 
    M += .1
    
plots.xlabel('Extra Credit')
plots.ylabel('Final Grade')
plots.show()
